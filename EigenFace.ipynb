# %%
run eigen.py

# %%
eigen_face = EigenFace()

# %%
eigen_face.vector_matrix.shape
# Out:
# (11, 1610)

# %%
pca = eigen_face.get_pca()

# %%
print(pca.eigen_vector.shape)
print(pca.variance_proportion.shape)
# Out:
# (11, 1610)
# (1610,)

# %%
eigen_face.plot_image_dictionary()
plt.show()

# %%
eigen_face.plot_eigen_vectors()
plt.show()

# %%
eigen_face.plot_pca_components_proportions()
plt.show()

# %%
eigen_face.pca.eigen_vector[0].shape
# Out:
# (1610,)

# %%
eigen_face.plot_eigen_vector(4)
plt.show()

# %%
eigen_face.plot_mean_vector()
plt.show()

# %%
aa = eigen_face.pca.eigen_vector[0]
eigen_face.pca.eigen_vector.shape
# Out:
# (11, 1610)

# %%
for ii in range(1,eigen_face.pca.eigen_vector.shape[0]-1):
    aa += eigen_face.pca.eigen_vector[ii]

# %%
plt.imshow(np.reshape(aa, eigen_face.get_image_shape()), cmap=plt.cm.gray)
plt.show()

# %%
eigen_face.plot_eigen_value_distribution(range(0,100))
plt.show()
