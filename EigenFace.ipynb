# %%
run eigen.py

# %%
eigen_face = EigenFace()

# %%
eigen_face.vector_matrix.shape
# Out:
# (11, 1610)

# %%
pca = eigen_face.get_pca()

# %%
print(pca.u.shape)
print(pca.s.shape)
print(pca.weight_matrix.shape)
print(pca.projected_matrix.shape)
print(pca.standard_deviation.shape)
print(pca.variance_proportion.shape)
# Out:
# (11, 11)
# (11,)
# (1610, 1610)
# (11, 1610)
# (11,)
# (11,)

# %%
v = pca.weight_matrix[:]
num_row_x = num_row_y = int(np.floor(np.sqrt(len(25)-1))) + 1
print(v[0].shape)
plt.imshow(np.reshape(v[0], (35,46)), cmap=plt.cm.gray)
plt.show()
# Out:
# (1610,)

# %%
eigen_face.plot_image_dictionary()
plt.show()

# %%
eigen_face.plot_u_matrix()
plt.show()

# %%
eigen_face.plot_pca_components_proportions()
plt.show()
